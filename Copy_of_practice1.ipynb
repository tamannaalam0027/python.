# %% [markdown]
# <a href="https://colab.research.google.com/github/tamannaalam0027/python./blob/main/Copy_of_practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 20
b = 10
sub = a-b
mul = a*b
div = a/b
print("subtraction :",sub)
print("multipication :",mul)
print("division :",div)
# Out:
# subtraction : 10
# multipication : 200
# division : 2.0

# %%
id = " UG01"
name = "Oreo"
batch = 12
hometown = "Bogura"
print("ID :",id)
print("NAME :",name)
print("BATCH :",batch)
print("HOME TOWN :",hometown)
# Out:
# ID :  UG01
# NAME : Oreo
# BATCH : 12
# HOME TOWN : Bogura

# %%
a = 102
print("Before :",a)
a = 455
print("After :",a)
# Out:
# Before : 102
# After : 455

# %%
a = "267"
b = "567"
sum = int(a)+ int(b)
print(a)
print(b)
print(sum)
print(type(a), type(b), type(sum))
# Out:
# 267
# 567
# 834
# <class 'str'> <class 'str'> <class 'int'>

# %%
a = 16
b = 33
c = 58
avg = (a+b+c)/3
print("Average of 3 numbers :{:.2f}".format(avg))
# Out:
# Average of 3 numbers :35.67

# %%
a = int(input("Enter a number:"))
b = int(input("Enter a number:"))
print("Addition:",a+b)
print("Subtraction:",a-b)
print("Multipication:",a*b)
print("Division:",a/b)
# Out:
# Enter a number:30
# Enter a number:10
# Addition: 40
# Subtraction: 20
# Multipication: 300
# Division: 3.0

# %%
char = input("Enter a character:")
if  char =='a'or char =='e' or char =='i' or char =='o' or char =='u':
  print("vowel")
else:
  print("consonant")
# Out:
# Enter a character:f
# consonant

# %%
c =int(input("Enter temparature in celcius:"))
f =int(input("Enter temparature in fahrenheit:"))
print("celcius to fahrenheit:",((c*9/5)+32))
print("fahrenheit to celcius:",((f-32)*5/9))
# Out:
# Enter temparature in celcius:47
# Enter temparature in fahrenheit:60
# celcius to fahrenheit: 116.6
# fahrenheit to celcius: 15.555555555555555

# %%
a =int(input("Enter a number:"))
b =int(input("Enter a number:"))
c =int(input("Enter a number:"))
if a>b and a>c:
    print(a," is greater")
elif b>a and b>c:
     print(b," is greater")
else:
    print(c," is greater")
# Out:
# Enter a number:30
# Enter a number:40
# Enter a number:50
# 50  is greater

# %%
N =int(input("Enter a number:"))
for i in range(1,N+1):
   if i%2==0:
      print(i)
# Out:
# Enter a number:10
# 2
# 4
# 6
# 8
# 10

# %%
N = int(input("Enter a number:"))
sum = 0
for i in range(1,N+1):
  if i%3==0 or i%5==0:
    sum = sum+i
    print("Sum:",sum)
# Out:
# Enter a number:10
# Sum: 3
# Sum: 8
# Sum: 14
# Sum: 23
# Sum: 33

# %%
N = int(input("Enter a number:"))
for i in range(1,11):
    print(N,"x",i ,"=",N*i)
# Out:
# Enter a number:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
